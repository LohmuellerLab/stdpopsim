# %% [markdown]
# #QC for arabidopsis thaliana model
#
# To QC, the A. thaliana demographic model was set up in msprime separately
#
# Then, msprime's built-in demographic model checker is used to output summaries for each model
#
# Summaries are manually checked for consistency

# %%
import msprime
from stdpopsim import arabidopsis_thaliana
import allel
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm
from allel.util import asarray_ndim, check_integer_dtype

# %% [markdown]
# Set up simulations with A. thaliana implementation from Arun and Chris

# %%
ch = "chr5"
sample_size = 50
chrom = arabidopsis_thaliana.genome.chromosomes[ch]
recomb_map = chrom.recombination_map()
model = arabidopsis_thaliana.Durvasula2017MSMC()

# %% [markdown]
# print demographic history

# %%
dd_ac = msprime.DemographyDebugger(**model.asdict())
dd_ac.print_history()
# Out:
# =============================
# Epoch: 0 -- 699.0 generations
# =============================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |7.89e+04 7.89e+04              0 |     0
#
# Events @ generation 699.0
#    - Population parameter change for 0: initial_size -> 78908
# ==================================
# Epoch: 699.0 -- 2796.0 generations
# ==================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |7.89e+04 7.89e+04              0 |     0
#
# Events @ generation 2796.0
#    - Population parameter change for 0: initial_size -> 78908
# ===================================
# Epoch: 2796.0 -- 6068.0 generations
# ===================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |7.89e+04 7.89e+04              0 |     0
#
# Events @ generation 6068.0
#    - Population parameter change for 0: initial_size -> 78908
# ===================================
# Epoch: 6068.0 -- 9894.0 generations
# ===================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |7.89e+04 7.89e+04              0 |     0
#
# Events @ generation 9894.0
#    - Population parameter change for 0: initial_size -> 78908
# ====================================
# Epoch: 9894.0 -- 14370.0 generations
# ====================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |7.89e+04 7.89e+04              0 |     0
#
# Events @ generation 14370.0
#    - Population parameter change for 0: initial_size -> 78908
# =====================================
# Epoch: 14370.0 -- 19606.0 generations
# =====================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |7.89e+04 7.89e+04              0 |     0
#
# Events @ generation 19606.0
#    - Population parameter change for 0: initial_size -> 78908
# =====================================
# Epoch: 19606.0 -- 25730.0 generations
# =====================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |7.89e+04 7.89e+04              0 |     0
#
# Events @ generation 25730.0
#    - Population parameter change for 0: initial_size -> 78908
# =====================================
# Epoch: 25730.0 -- 32894.0 generations
# =====================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |7.89e+04 7.89e+04              0 |     0
#
# Events @ generation 32894.0
#    - Population parameter change for 0: initial_size -> 78908
# =====================================
# Epoch: 32894.0 -- 41275.0 generations
# =====================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |7.89e+04 7.89e+04              0 |     0
#
# Events @ generation 41275.0
#    - Population parameter change for 0: initial_size -> 78908
# =====================================
# Epoch: 41275.0 -- 51077.0 generations
# =====================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |7.89e+04 7.89e+04              0 |     0
#
# Events @ generation 51077.0
#    - Population parameter change for 0: initial_size -> 111132
# =====================================
# Epoch: 51077.0 -- 62544.0 generations
# =====================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |1.11e+05 1.11e+05              0 |     0
#
# Events @ generation 62544.0
#    - Population parameter change for 0: initial_size -> 110745
# =====================================
# Epoch: 62544.0 -- 75958.0 generations
# =====================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |1.11e+05 1.11e+05              0 |     0
#
# Events @ generation 75958.0
#    - Population parameter change for 0: initial_size -> 96283
# =====================================
# Epoch: 75958.0 -- 91648.0 generations
# =====================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |9.63e+04 9.63e+04              0 |     0
#
# Events @ generation 91648.0
#    - Population parameter change for 0: initial_size -> 87661
# ======================================
# Epoch: 91648.0 -- 110001.0 generations
# ======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |8.77e+04 8.77e+04              0 |     0
#
# Events @ generation 110001.0
#    - Population parameter change for 0: initial_size -> 83932
# =======================================
# Epoch: 110001.0 -- 131471.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |8.39e+04 8.39e+04              0 |     0
#
# Events @ generation 131471.0
#    - Population parameter change for 0: initial_size -> 83829
# =======================================
# Epoch: 131471.0 -- 156584.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |8.38e+04 8.38e+04              0 |     0
#
# Events @ generation 156584.0
#    - Population parameter change for 0: initial_size -> 91813
# =======================================
# Epoch: 156584.0 -- 185960.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |9.18e+04 9.18e+04              0 |     0
#
# Events @ generation 185960.0
#    - Population parameter change for 0: initial_size -> 111644
# =======================================
# Epoch: 185960.0 -- 220324.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |1.12e+05 1.12e+05              0 |     0
#
# Events @ generation 220324.0
#    - Population parameter change for 0: initial_size -> 143456
# =======================================
# Epoch: 220324.0 -- 260520.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |1.43e+05 1.43e+05              0 |     0
#
# Events @ generation 260520.0
#    - Population parameter change for 0: initial_size -> 181571
# =======================================
# Epoch: 260520.0 -- 307540.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |1.82e+05 1.82e+05              0 |     0
#
# Events @ generation 307540.0
#    - Population parameter change for 0: initial_size -> 217331
# =======================================
# Epoch: 307540.0 -- 362541.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |2.17e+05 2.17e+05              0 |     0
#
# Events @ generation 362541.0
#    - Population parameter change for 0: initial_size -> 241400
# =======================================
# Epoch: 362541.0 -- 426879.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |2.41e+05 2.41e+05              0 |     0
#
# Events @ generation 426879.0
#    - Population parameter change for 0: initial_size -> 246984
# =======================================
# Epoch: 426879.0 -- 502139.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |2.47e+05 2.47e+05              0 |     0
#
# Events @ generation 502139.0
#    - Population parameter change for 0: initial_size -> 238593
# =======================================
# Epoch: 502139.0 -- 590173.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |2.39e+05 2.39e+05              0 |     0
#
# Events @ generation 590173.0
#    - Population parameter change for 0: initial_size -> 228222
# =======================================
# Epoch: 590173.0 -- 693151.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |2.28e+05 2.28e+05              0 |     0
#
# Events @ generation 693151.0
#    - Population parameter change for 0: initial_size -> 217752
# =======================================
# Epoch: 693151.0 -- 813610.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |2.18e+05 2.18e+05              0 |     0
#
# Events @ generation 813610.0
#    - Population parameter change for 0: initial_size -> 198019
# =======================================
# Epoch: 813610.0 -- 954517.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |1.98e+05 1.98e+05              0 |     0
#
# Events @ generation 954517.0
#    - Population parameter change for 0: initial_size -> 165210
# ========================================
# Epoch: 954517.0 -- 1119341.0 generations
# ========================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |1.65e+05 1.65e+05              0 |     0
#
# Events @ generation 1119341.0
#    - Population parameter change for 0: initial_size -> 121796
# =========================================
# Epoch: 1119341.0 -- 1312147.0 generations
# =========================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |1.22e+05 1.22e+05              0 |     0
#
# Events @ generation 1312147.0
#    - Population parameter change for 0: initial_size -> 121796
# =========================================
# Epoch: 1312147.0 -- 1537686.0 generations
# =========================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |1.22e+05 1.22e+05              0 |     0
#
# Events @ generation 1537686.0
#    - Population parameter change for 0: initial_size -> 73989
# =========================================
# Epoch: 1537686.0 -- 1801500.0 generations
# =========================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 | 7.4e+04  7.4e+04              0 |     0
#
# Events @ generation 1801500.0
#    - Population parameter change for 0: initial_size -> 73989
# =========================================
# Epoch: 1801500.0 -- 2110100.0 generations
# =========================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 | 7.4e+04  7.4e+04              0 |     0
#
# Events @ generation 2110100.0
#    - Population parameter change for 0: initial_size -> 73989
# ===================================
# Epoch: 2110100.0 -- inf generations
# ===================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 | 7.4e+04  7.4e+04              0 |     0

# %% [markdown]
# ##Bernard's version of the demographic model

# %% [markdown]
# Set times and sizes

# %%
times = [
           699, 2796, 6068, 9894, 14370, 19606, 25730, 32894, 41275,
           51077, 62544, 75958, 91648, 110001, 131471, 156584, 185960, 220324,
           260520, 307540, 362541, 426879, 502139, 590173, 693151, 813610,
           954517, 1119341, 1312147, 1537686, 1801500, 2110100
        ]

sizes = [
           42252426, 42252426, 60323, 72174, 40591, 21158, 21442,
           39942, 78908, 111132, 110745, 96283, 87661, 83932, 83829, 91813,
           111644, 143456, 181571, 217331, 241400, 246984, 238593, 228222,
           217752, 198019, 165210, 121796, 121796, 73989, 73989, 73989
        ]

#mask first 7 and last 2 entries to the closest non-masked size
mask_first = 8
mask_last = 2
sizes = (
    [sizes[mask_first]]*mask_first + 
    sizes[mask_first:-mask_last] + 
    [sizes[-mask_last]]*mask_last
)

# %% [markdown]
# set up demographic model

# %%
population_configurations = [
    msprime.PopulationConfiguration(
        sample_size=0, initial_size=sizes[0]
    )
]

migration_matrix = [
    [0],
]

demographic_events = [msprime.PopulationParametersChange(
    time=x, initial_size=y, population_id=0) for x,y in zip(times,sizes)]

# %% [markdown]
# Print demographic history

# %%
dd_b = msprime.DemographyDebugger(
    population_configurations=population_configurations,
    migration_matrix=migration_matrix,
    demographic_events=demographic_events)
dd_b.print_history()
# Out:
# =============================
# Epoch: 0 -- 699.0 generations
# =============================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |7.89e+04 7.89e+04              0 |     0
#
# Events @ generation 699.0
#    - Population parameter change for 0: initial_size -> 78908
# ==================================
# Epoch: 699.0 -- 2796.0 generations
# ==================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |7.89e+04 7.89e+04              0 |     0
#
# Events @ generation 2796.0
#    - Population parameter change for 0: initial_size -> 78908
# ===================================
# Epoch: 2796.0 -- 6068.0 generations
# ===================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |7.89e+04 7.89e+04              0 |     0
#
# Events @ generation 6068.0
#    - Population parameter change for 0: initial_size -> 78908
# ===================================
# Epoch: 6068.0 -- 9894.0 generations
# ===================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |7.89e+04 7.89e+04              0 |     0
#
# Events @ generation 9894.0
#    - Population parameter change for 0: initial_size -> 78908
# ====================================
# Epoch: 9894.0 -- 14370.0 generations
# ====================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |7.89e+04 7.89e+04              0 |     0
#
# Events @ generation 14370.0
#    - Population parameter change for 0: initial_size -> 78908
# =====================================
# Epoch: 14370.0 -- 19606.0 generations
# =====================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |7.89e+04 7.89e+04              0 |     0
#
# Events @ generation 19606.0
#    - Population parameter change for 0: initial_size -> 78908
# =====================================
# Epoch: 19606.0 -- 25730.0 generations
# =====================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |7.89e+04 7.89e+04              0 |     0
#
# Events @ generation 25730.0
#    - Population parameter change for 0: initial_size -> 78908
# =====================================
# Epoch: 25730.0 -- 32894.0 generations
# =====================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |7.89e+04 7.89e+04              0 |     0
#
# Events @ generation 32894.0
#    - Population parameter change for 0: initial_size -> 78908
# =====================================
# Epoch: 32894.0 -- 41275.0 generations
# =====================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |7.89e+04 7.89e+04              0 |     0
#
# Events @ generation 41275.0
#    - Population parameter change for 0: initial_size -> 78908
# =====================================
# Epoch: 41275.0 -- 51077.0 generations
# =====================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |7.89e+04 7.89e+04              0 |     0
#
# Events @ generation 51077.0
#    - Population parameter change for 0: initial_size -> 111132
# =====================================
# Epoch: 51077.0 -- 62544.0 generations
# =====================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |1.11e+05 1.11e+05              0 |     0
#
# Events @ generation 62544.0
#    - Population parameter change for 0: initial_size -> 110745
# =====================================
# Epoch: 62544.0 -- 75958.0 generations
# =====================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |1.11e+05 1.11e+05              0 |     0
#
# Events @ generation 75958.0
#    - Population parameter change for 0: initial_size -> 96283
# =====================================
# Epoch: 75958.0 -- 91648.0 generations
# =====================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |9.63e+04 9.63e+04              0 |     0
#
# Events @ generation 91648.0
#    - Population parameter change for 0: initial_size -> 87661
# ======================================
# Epoch: 91648.0 -- 110001.0 generations
# ======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |8.77e+04 8.77e+04              0 |     0
#
# Events @ generation 110001.0
#    - Population parameter change for 0: initial_size -> 83932
# =======================================
# Epoch: 110001.0 -- 131471.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |8.39e+04 8.39e+04              0 |     0
#
# Events @ generation 131471.0
#    - Population parameter change for 0: initial_size -> 83829
# =======================================
# Epoch: 131471.0 -- 156584.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |8.38e+04 8.38e+04              0 |     0
#
# Events @ generation 156584.0
#    - Population parameter change for 0: initial_size -> 91813
# =======================================
# Epoch: 156584.0 -- 185960.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |9.18e+04 9.18e+04              0 |     0
#
# Events @ generation 185960.0
#    - Population parameter change for 0: initial_size -> 111644
# =======================================
# Epoch: 185960.0 -- 220324.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |1.12e+05 1.12e+05              0 |     0
#
# Events @ generation 220324.0
#    - Population parameter change for 0: initial_size -> 143456
# =======================================
# Epoch: 220324.0 -- 260520.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |1.43e+05 1.43e+05              0 |     0
#
# Events @ generation 260520.0
#    - Population parameter change for 0: initial_size -> 181571
# =======================================
# Epoch: 260520.0 -- 307540.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |1.82e+05 1.82e+05              0 |     0
#
# Events @ generation 307540.0
#    - Population parameter change for 0: initial_size -> 217331
# =======================================
# Epoch: 307540.0 -- 362541.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |2.17e+05 2.17e+05              0 |     0
#
# Events @ generation 362541.0
#    - Population parameter change for 0: initial_size -> 241400
# =======================================
# Epoch: 362541.0 -- 426879.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |2.41e+05 2.41e+05              0 |     0
#
# Events @ generation 426879.0
#    - Population parameter change for 0: initial_size -> 246984
# =======================================
# Epoch: 426879.0 -- 502139.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |2.47e+05 2.47e+05              0 |     0
#
# Events @ generation 502139.0
#    - Population parameter change for 0: initial_size -> 238593
# =======================================
# Epoch: 502139.0 -- 590173.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |2.39e+05 2.39e+05              0 |     0
#
# Events @ generation 590173.0
#    - Population parameter change for 0: initial_size -> 228222
# =======================================
# Epoch: 590173.0 -- 693151.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |2.28e+05 2.28e+05              0 |     0
#
# Events @ generation 693151.0
#    - Population parameter change for 0: initial_size -> 217752
# =======================================
# Epoch: 693151.0 -- 813610.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |2.18e+05 2.18e+05              0 |     0
#
# Events @ generation 813610.0
#    - Population parameter change for 0: initial_size -> 198019
# =======================================
# Epoch: 813610.0 -- 954517.0 generations
# =======================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |1.98e+05 1.98e+05              0 |     0
#
# Events @ generation 954517.0
#    - Population parameter change for 0: initial_size -> 165210
# ========================================
# Epoch: 954517.0 -- 1119341.0 generations
# ========================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |1.65e+05 1.65e+05              0 |     0
#
# Events @ generation 1119341.0
#    - Population parameter change for 0: initial_size -> 121796
# =========================================
# Epoch: 1119341.0 -- 1312147.0 generations
# =========================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |1.22e+05 1.22e+05              0 |     0
#
# Events @ generation 1312147.0
#    - Population parameter change for 0: initial_size -> 121796
# =========================================
# Epoch: 1312147.0 -- 1537686.0 generations
# =========================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 |1.22e+05 1.22e+05              0 |     0
#
# Events @ generation 1537686.0
#    - Population parameter change for 0: initial_size -> 73989
# =========================================
# Epoch: 1537686.0 -- 1801500.0 generations
# =========================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 | 7.4e+04  7.4e+04              0 |     0
#
# Events @ generation 1801500.0
#    - Population parameter change for 0: initial_size -> 73989
# =========================================
# Epoch: 1801500.0 -- 2110100.0 generations
# =========================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 | 7.4e+04  7.4e+04              0 |     0
#
# Events @ generation 2110100.0
#    - Population parameter change for 0: initial_size -> 73989
# ===================================
# Epoch: 2110100.0 -- inf generations
# ===================================
#      start     end      growth_rate |     0
#    -------- --------       -------- | --------
# 0 | 7.4e+04  7.4e+04              0 |     0
